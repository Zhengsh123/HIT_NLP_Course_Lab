# %%
from LM_Bi import *

# %%
##做了未登录词处理
from score import *
calc('./dataset/199801_seg&pos.txt','./output/seg_Bigram.txt')
# Out:
# 十
# 高
# 同
# 推
# 一
# 代表
# 中
# 再
# 大
# 未
# 顺
# 对
# 面
# 不
# 还有
# 各
# 进
# 一
# 民心
# 民
# 直
# 早
# 日
# 各
# 发展
# 人
# 科
# 重
# 和
# 美
# 代表
# 生
# 国
# 国
# 各条
# 阶
# 大
# 对
# 才能
# 各
# 勇
# 局
# 进
# 结出
# 上
# 重
# 两
# 同
# 重
# 离不开
# 两
# 当
# 意
# 健
# 首
# 一
# 领导
# 泽
# 首
# 一
# 领导
# 泽
# 首
# 一
# 音乐
# 中
# 北京市
# 音乐
# 中
# 中
# 燮
# 名
# 城
# 中
# 东
# 带到
# 无人
# 音乐
# 梁山
# 人大
# 报以
# 选
# 选
# 领导
# 将
# 慰
# 北京市
# 总
# 多
# 所属
# 握
# 慰
# 机
# 再
# 总
# 一
# 电
# 还有
# 同
# 最
# 成
# 孙
# 带来
# 不能
# 一
# 改
# 十
# 一
# 当
# 一
# 现
# 负责
# 还有
# 来
# 主力
# 不
# 新世纪
# 最
# 实
# １０
# ４４
# 自治
# 十
# 提
# 不断
# １２月
# 地市
# 安多
# 有
# 地
# 大
# 送到
# 为
# 没
# 大
# 没
# 现
# 各方
# ２０
# ２０
# 小
# 过后
# 下
# 小
# 新
# 侨
# 美
# 代表
# 泽
# 所
# 和
# 大
# 作
# 侨
# 上岗制
# 资格证
# 电视部
# 上岗制
# 电视部
# 资格证
# 才能
# 上
# 资格证
# 颁证
# 主持人
# 你
# 中看
# 颁证
# 电视部
# 全社
# 记
# 工
# 本
# 重
# 全社
# 贵州省
# 一
# 同
# 面
# 基本
# 成
# 用
# 一家
# 一家
# 做到
# 贫困面
# 贵州省
# 记
# 重
# 进
# 革命
# 军医大
# 新
# 千里
# ４０
# 治污
# 家正
# 对
# 关停
# 进
# 处理
# 第
# 新
# １１月
# 人
# ５２３６
# 国
# １１０
# １２
# １８
# 人
# ５４００
# １１５
# 创新
# 上
# 推
# 新
# 来
# 和
# 这
# 提
# 招待
# 和
# ...

# %%
##没做未登录词处理
calc('./dataset/199801_seg&pos.txt','./output/seg_Bigram.txt')
# Out:
# (0.9024135736652015, 0.9383889122129209, 0.9200497046850792)

# %%
##做了未登录词处理
calc('./dataset/199803_seg&pos.txt','./output/seg_Bigram_OOV.txt')
# Out:
# (0.8969888168064836, 0.8769811094054577, 0.8868721347120023)

# %%
##没做未登录词处理，使用sent3测试
calc('./dataset/199803_seg&pos.txt','./output/seg_Bigram_OOV.txt')
# Out:
# (0.834523456008265, 0.9041265570235417, 0.8679318015480747)

# %%
##没改之前的HMM
print(calc('./dataset/199801_seg&pos.txt','./output/hmm_seg.txt'))
# Out:
# (0.7886814768057069, 0.8147565453125561, 0.8015069950072923)

# %%
##做了未登录词处理
calc('./dataset/199803_seg&pos.txt','./output/seg_Bigram_OOV.txt')
# Out:
# (0.8969888168064836, 0.8769811094054577, 0.8868721347120023)

# %%
##做了未登录词处理,两个文件
calc('./dataset/199803_seg&pos.txt','./output/seg_Bigram_OOV.txt')
# Out:
# (0.8999974005887666, 0.8757906652100984, 0.8877290452950617)

# %%
##一元文法
calc('./dataset/199801_seg&pos.txt','./output/seg.txt')
# Out:
# (0.9313746927705738, 0.9631862049501679, 0.9470133758123708)

# %%
##一元文法
calc('./dataset/199801_seg&pos.txt','./output/seg_withLM1.txt')
# Out:
# (0.9313746927705738, 0.9631862049501679, 0.9470133758123708)

# %%
##二元文法
calc('./dataset/199801_seg&pos.txt','./output/seg_withLM2.txt')
# Out:
# (0.8848965652919921, 0.9343343287192653, 0.9089437091682996)

# %%
##HMM
calc('./dataset/199801_seg&pos.txt','./output/seg_HMM.txt')
# Out:
# (0.7818358603506427, 0.541263231518821, 0.6396784744107998)

# %%
##没有HMM，Uni，sent1测试
calc('./dataset/199801_seg&pos.txt','./output/seg.txt')
# Out:
# 新世纪
# １
# ３
# １
# 新世纪
# １
# １
# １
# ２
# 还有
# １
# １
# 一部分
# ２
# 新世纪
# １
# ３
# 写下
# １
# 各条
# ２
# ２
# 才能
# 结出
# ２
# ２
# 上来
# 离不开
# １
# 高地
# ９
# １
# ３
# １
# １
# ９
# 题为
# ２
# 报以
# 所属
# 一
# 就是
# 还有
# 带来
# 只是
# 一
# 可不
# 还有
# 阳安
# ３
# １
# １
# 新世纪
# １
# ３
# １
# １
# ３
# １
# ４
# ８
# １
# ３
# ９
# 不断
# １
# ９
# ４
# ５
# １
# ９
# ２
# ９
# ４
# 自有
# １
# １
# ２
# ２
# ２
# 过后
# １
# １
# ３
# １
# ９
# ２
# 对此
# 新世纪
# １
# ３
# 电视部
# １
# １
# １
# 电视部
# １
# 提出
# 才能
# 新世纪
# 电视部
# １
# ３
# １
# ２
# ３
# 一家
# 一家
# 做到
# 做到
# １
# ３
# １
# １
# 千里
# ４
# 治污
# １
# １
# ２
# １
# １
# １
# ３
# ５
# １
# １
# １
# １
# ３
# 第
# ９
# ９
# 江苏省
# ９
# １
# １
# １
# １
# ５
# １
# １
# １
# ５
# １
# 创新
# ９
# ９
# ２
# １
# ３
# 做好
# ２
# ２
# 创新
# 超计划
# 浅海
# 新井
# 共建
# １
# １
# ２
# ２
# １
# ０
# １
# ２
# ２
# １
# ０
# ０
# 过重
# ２
# １
# ２
# ２
# ３
# ２
# 只能
# 不
# １
# ３
# 上钩
# １
# ２
# １
# ３
# ４
# ３
# １
# １
# ２
# 出生于
# １
# １
# １
# １
# １
# １
# １
# １
# １
# ３
# １
# １
# 中南
# １
# ３
# ３
# 中南
# 很快
# 有着
# １
# 只有
# １
# １
# １
# １
# ７
# 有着
# １
# 谈到
# １
# ３
# 多年
# １
# ２
# 对此
# １
# １
# １
# ...

# %%
##有HMM，BI，sent1测试
calc('./dataset/199801_seg&pos.txt','./output/seg_Bigram_OOV.txt')
# Out:
# 新世纪
# 新世纪
# 年中
# 年中
# 还有
# 一部分
# 不会
# 新世纪
# 写下
# 各条
# 才能
# 结出
# 上来
# 离不开
# 高地
# 健
# 北京市
# 题为
# 中
# 优
# 城
# 东
# 带到
# 无人
# 梁山
# 人大
# 报以
# 北京市
# 所属
# 就是
# 还有
# 带来
# 不能
# 回
# 只是
# 不能
# 还有
# 新世纪
# １０
# ４４
# 自治
# 不断
# １２月
# 地市
# 自有
# 送到
# 各方
# ２０
# ２０
# 过后
# 和美
# 对此
# 和衷
# 新世纪
# 上岗制
# 资格证
# 电视部
# 上岗制
# 电视部
# 资格证
# 才能
# 资格证
# 颁证
# 主持人
# 中看
# 新世纪
# 电视部
# 全社
# 全社
# 贵州省
# 一家
# 一家
# 做到
# 做到
# 贫困面
# 贵州省
# 军医大
# 千里
# 治污
# 下一
# 第
# １１月
# ５２３６
# １１０
# １２
# １８
# ５４００
# １１５
# 创新
# 做好
# 超计划
# 浅海
# 新井
# 延安城
# 共建
# ０
# ２
# １
# ０
# ０
# 过重
# 只能
# 不
# １３
# 上钩
# 不能
# 出生于
# 提
# 中南
# 副总
# 中南
# 当地人
# 很快
# 展
# 有着
# 只有
# １４００
# １３
# １６
# ７０００
# 有着
# １３
# 谈到
# 不能
# 多年
# 极
# 不到
# 是非
# 对此
# １６
# １４
# 第
# 谈到
# 国都
# 中南
# 副总
# 取
# 正在
# 始于
# 局
# 和
# 为首
# 副总
# 中南
# 招待
# 来讲
# 下发
# 全人类
# 不是
# 南
# 遭
# 取
# 谈到
# 政治局
# 谈到
# 还有
# 还有
# 成
# 才能
# 首批
# 在内
# 首批
# 谈到
# 呈
# 取
# 谈到
# 谈到
# 各方
# 何方
# 应约
# 何方
# ６０
# ６０
# 正面
# 副总
# 最好
# 所在
# 沿
# 大港
# 大港
# 省市
# 展
# 主席会
# 正在
# 老是
# 取
# 国是
# 几分
# 不够
# 取
# 还有
# １４００
# 就是
# 谈到
# 为此
# ３００
# ５０
# ...

# %%
##有HMM，Bi，sent3测试
calc('./dataset/199803_seg&pos.txt','./output/seg_Bigram3.txt')
# Out:
# 第
# 闭
# 苏宁
# 人大代表
# 委员
# 人民法院
# 人民代表
# 人民代表
# 人民代表
# 人民代表
# 人民代表
# 和县
# 人民代表
# 人民代表
# 人民代表
# 人民代表
# 人民代表
# 人民代表
# 人民代表
# 已
# 各省
# 人民代表
# 人民代表
# 人大代表
# 现实
# 人民代表
# 人民代表
# 人民代表
# 人大代表
# 二千
# 健
# 人大代表
# 人大代表
# 病逝
# 现实
# 人大代表
# 人大代表
# 病逝
# 人大代表
# 代表人
# ５３
# ５２
# 本届
# 呈
# 积
# 大河
# 梅
# 人大代表
# 大幅度
# 届时
# 人大代表
# 开馆
# 开馆
# 还有
# 及其
# 楹联
# 书画
# 妇
# 开馆
# ３９
# 多元
# 井冈山
# 井冈山
# 这部
# 一带
# 结对
# 田园
# 路桥
# 投劳
# ３
# 四通
# 四有
# 通路
# 通电
# 通电话
# 村部
# ７０
# 扶智
# 设在
# 世
# 还是
# 审看
# 世
# 就是
# 还是
# 说
# 襟
# 还有
# 登山队
# 钟
# 崇
# 红
# 导
# 洪
# 赞叹
# 铁
# 以情动人
# 报
# 签
# 代
# 人民代表
# 人民代表
# 人民代表
# 人民代表
# 各国
# 盐
# 西海
# 盐
# 西海
# ２９
# ７６
# ４７
# 西海
# 打
# 生产能力
# 西海
# ４７
# ３６
# ７
# 盐
# １
# 西海
# １００
# １００
# ４４０
# 石
# ２２
# １
# １０００
# 二千
# ２７００
# 着重
# 这项
# 人民代表
# 玲
# 昭
# 达
# 振
# 小
# 乾
# 铭
# 福
# 周
# 永
# 占
# 恭
# 善
# 伦
# 若
# 明
# 益
# 志
# 爱
# 丽
# 瑶
# 明
# 王家
# 黔
# 兆
# 如
# 志
# 怀
# 学
# 松
# 元
# 应
# 宏
# 慧
# 昭
# 克
# 陆
# 和
# 璧
# 德
# 士
# 士
# 世
# 世
# 义
# 祥
# 锡
# 天
# 兰
# 家
# 加
# 宝
# 承
# 保
# 辅
# 韶
# 庄
# 礼
# 桂
# 又
# 修
# 吉
# 宜
# 彦
# 海
# 芳
# 路
# 长
# 永
# ...
